# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
import warnings
warnings.filterwarnings("ignore")
import skgstat as skg

# %%
# Baca file CSV (pastikan kolom: x, y, nilai)
df = pd.read_excel('gempasumatra.xlsx')

# Ambil koordinat dan nilai
coords = df[[' Latitude ', ' Longitude ']].to_numpy()
vals = df[[' Magnitude ']].to_numpy()
print(df.get('sample'))
# make a nice table
pd.DataFrame({'x': coords[:, 0], 'y': coords[:, 1], 'lead': vals.flatten()}).head()
# Out:
# None
#        x        y  lead
# 0 -4.880  102.995   4.3
# 1 -6.090  105.333   4.0
# 2 -2.078   99.397   3.5
# 3 -6.080  104.421   5.0
# 4 -4.785  103.209   4.9

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 9))
art = ax.scatter(coords[:, 0], coords[:, 1], s=50, c=vals.flatten(), cmap='plasma')
plt.colorbar(art)
plt.xlabel('Longitude')
plt.ylabel('Latitude')  
plt.show()

# %%
V = skg.Variogram(coords, vals.flatten(), maxlag='median', n_lags=15, normalize=False) 
fig = V.plot(show=False)

# %%
print('Sample variance: %.2f   Variogram sill: %.2f' % (vals.flatten().var(), V.describe()['sill']))
# Out:
# Sample variance: 0.32   Variogram sill: 0.31

# %%
pprint(V.describe())
# Out:
# {'dist_func': 'euclidean',
#  'effective_range': 0.48376630294566925,
#  'estimator': 'matheron',
#  'kwargs': {},
#  'model': 'spherical',
#  'normalized_effective_range': 2.0343337775998522,
#  'normalized_nugget': 0,
#  'normalized_sill': 0.10177425678991024,
#  'nugget': 0,
#  'params': {'bin_func': 'even',
#             'dist_func': 'euclidean',
#             'estimator': 'matheron',
#             'fit_method': 'trf',
#             'fit_sigma': None,
#             'maxlag': 4.205199422143968,
#             'model': 'spherical',
#             'n_lags': 15,
#             'normalize': False,
#             'use_nugget': False,
#             'verbose': False},
#  'sill': 0.3107434802718646}

# %%
print(V)
# Out:
# spherical Variogram
# -------------------
# Estimator:         matheron
# Effective Range:   0.48
# Sill:              0.31
# Nugget:            0.00

# %%
ok = skg.OrdinaryKriging(V, min_points=5, max_points=15, mode='exact')

# %%
# build the target grid
x = coords[:, 0]
y = coords[:, 1]
xx, yy = np.mgrid[x.min():x.max():100j, y.min():y.max():100j]
field = ok.transform(xx.flatten(), yy.flatten()).reshape(xx.shape)
s2 = ok.sigma.reshape(xx.shape)

# %%
print(np.isnan(field).all(), np.isnan(s2).all())
print(np.min(field), np.max(field))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(np.isnan(field).all(), np.isnan(s2).all())
#       2 print(np.min(field), np.max(field))
#
# NameError: name 'field' is not defined

# %%
print("Field range:", field.min(), field.max())
print("S2 range:", s2.min(), s2.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print("Field range:", field.min(), field.max())
#       2 print("S2 range:", s2.min(), s2.max())
#
# NameError: name 'field' is not defined

# %%
print("Field all NaN:", np.isnan(field).all())
print("S2 all NaN:", np.isnan(s2).all())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print("Field all NaN:", np.isnan(field).all())
#       2 print("S2 all NaN:", np.isnan(s2).all())
#
# NameError: name 'field' is not defined

# %%
print("Field all NaN:", np.isnan(field).all())
# Out:
# Field all NaN: False

# %%
print("Field range:", np.nanmin(field), np.nanmax(field))
print("S2 range:", np.nanmin(s2), np.nanmax(s2))
# Out:
# Field range: nan nan
# S2 range: nan nan

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

x_ = (x - x.mean()) / x.std() * 15 + 50
y_ = (y - y.mean()) / y.std() * 15 + 50

art = axes[0].matshow(field.T, origin='lower', cmap='plasma', vmin=vals.min(), vmax=vals.max())
axes[0].set_title('Interpolation')
axes[0].plot(x_, y_, '+w')
axes[0].set_xlim((0, 100))
axes[0].set_ylim((0, 100))
plt.colorbar(art, ax=axes[0])
art = axes[1].matshow(s2.T, origin='lower', cmap='YlGn_r')
axes[1].set_title('Kriging Error')
plt.colorbar(art, ax=axes[1])
axes[1].plot(x_, y_, '+w')
axes[1].set_xlim((0, 100))
axes[1].set_ylim((0, 100))

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# rescale the coordinates to fit the interpolation raster
x_ = (x - x.min()) / (x.max() - x.min()) * 100
y_ = (y - y.min()) / (y.max() - y.min()) * 100

art = axes[0].matshow(field.T, origin='lower', cmap='plasma', vmin=vals.min(), vmax=vals.max())
axes[0].set_title('Interpolation')
axes[0].plot(x_, y_, '+w')
axes[0].set_xlim((0, 100))
axes[0].set_ylim((0, 100))
plt.colorbar(art, ax=axes[0])
plt.xlabel('Longitude')
plt.ylabel('Latitude')  

art = axes[1].matshow(s2.T, origin='lower', cmap='YlGn_r')
axes[1].set_title('Kriging Error')
plt.colorbar(art, ax=axes[1])
axes[1].plot(x_, y_, '+w')
axes[1].set_xlim((0, 100))
axes[1].set_ylim((0, 100))
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()
